# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (500, 510)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 500 to 510:
# california is never rainy during july , but it is sometimes beautiful in february .
# he dislikes grapefruit , strawberries , and grapes .
# paris is sometimes hot during winter , and it is warm in february .
# he likes limes , mangoes , and bananas .
# the mango is our least liked fruit , but the apple is your least liked .
# california is usually hot during august , and it is sometimes pleasant in july .
# the lemon is her favorite fruit , but the grape is my favorite .
# paris is usually rainy during may , but it is never mild in december .
# they like oranges , bananas , and apples .
# france is sometimes busy during july , and it is rainy in may .
#
# French sentences 500 to 510:
# california est jamais pluvieux en juillet , mais il est parfois beau en février .
# il aime pas le pamplemousse , les fraises et les raisins .
# paris est parfois chaud pendant l' hiver , et il est chaud en février .
# il aime citrons verts , mangues et les bananes .
# la mangue est notre fruit moins aimé , mais la pomme est votre moins aimé .
# californie est généralement chaud au mois d' août , et il est parfois agréable en juillet .
# le citron est son fruit préféré , mais le raisin est mon préféré .
# paris est généralement pluvieux au mois de mai , mais il est jamais doux en décembre .
# ils aiment les oranges , les bananes et les pommes .
# la france est parfois occupé en juillet , et il pleut en mai .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of each sentence from `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    source_sentences = source_text.split('\n')
    target_sentences = target_text.split('\n')
    source_id_text = [[source_vocab_to_int[w] for w in sentence.split()] for sentence in source_sentences]
    target_id_text = [[target_vocab_to_int[w] for w in (sentence + ' <EOS>').split()] for sentence in target_sentences]
    return (source_id_text, target_id_text)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) in [LooseVersion('1.0.0'), LooseVersion('1.0.1')], 'This project requires TensorFlow version 1.0  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoding_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
#
# Return the placeholders in the following the tuple (Input, Targets, Learing Rate, Keep Probability)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, and learning rate.
    :return: Tuple (input, targets, learning rate, keep probability)
    """
    input_ = tf.placeholder(tf.int32, shape=[None,None], name='input')
    targets = tf.placeholder(tf.int32, shape=[None,None])
    learn_rate = tf.placeholder(tf.float32)
    keep_prob = tf.placeholder(tf.float32, shape=None, name='keep_prob')
    return (input_, targets, learn_rate, keep_prob)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoding Input
# Implement `process_decoding_input` using TensorFlow to remove the last word id from each batch in `target_data` and concat the GO ID to the beginning of each batch.

# %%
def process_decoding_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for decoding
    :param target_data: Target Placeholder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_decoding_input(process_decoding_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer using [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn).

# %%
def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :return: RNN state
    """
    rnn_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)
    rnn_cell = tf.contrib.rnn.DropoutWrapper(rnn_cell, output_keep_prob=keep_prob)
    _, rnn_state = tf.nn.dynamic_rnn(rnn_cell, rnn_inputs, dtype=tf.float32)
    return rnn_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create training logits using [`tf.contrib.seq2seq.simple_decoder_fn_train()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_train) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).  Apply the `output_fn` to the [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder) outputs.

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope,
                         output_fn, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param sequence_length: Sequence Length
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Train Logits
    """
    train_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_train(encoder_state)
    train_outputs, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(
        dec_cell,
        train_decoder_fn,
        inputs=dec_embed_input,
        sequence_length=sequence_length,
        scope=decoding_scope
    )
    logits = output_fn(train_outputs)
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference logits using [`tf.contrib.seq2seq.simple_decoder_fn_inference()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/simple_decoder_fn_inference) and [`tf.contrib.seq2seq.dynamic_rnn_decoder()`](https://www.tensorflow.org/versions/r1.0/api_docs/python/tf/contrib/seq2seq/dynamic_rnn_decoder).

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id,
                         maximum_length, vocab_size, decoding_scope, output_fn, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param maximum_length: The maximum allowed time steps to decode
    :param vocab_size: Size of vocabulary
    :param decoding_scope: TensorFlow Variable Scope for decoding
    :param output_fn: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: Inference Logits
    """
    infer_decoder_fn = tf.contrib.seq2seq.simple_decoder_fn_inference(
        output_fn, 
        encoder_state, 
        dec_embeddings, 
        start_of_sequence_id, 
        end_of_sequence_id, 
        maximum_length, 
        vocab_size
    )
    infer_logits, _, _ = tf.contrib.seq2seq.dynamic_rnn_decoder(
        dec_cell,
        infer_decoder_fn,
        scope=decoding_scope
    )
    return infer_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# - Create RNN cell for decoding using `rnn_size` and `num_layers`.
# - Create the output fuction using [`lambda`](https://docs.python.org/3/tutorial/controlflow.html#lambda-expressions) to transform it's input, logits, to class logits.
# - Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, sequence_length, decoding_scope, output_fn, keep_prob)` function to get the training logits.
# - Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, maximum_length, vocab_size, decoding_scope, output_fn, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size,
                   num_layers, target_vocab_to_int, keep_prob):
    """
    Create decoding layer
    :param dec_embed_input: Decoder embedded input
    :param dec_embeddings: Decoder embeddings
    :param encoder_state: The encoded state
    :param vocab_size: Size of vocabulary
    :param sequence_length: Sequence Length
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param keep_prob: Dropout keep probability
    :return: Tuple of (Training Logits, Inference Logits)
    """
    dec_cell = tf.contrib.rnn.MultiRNNCell([tf.contrib.rnn.BasicLSTMCell(rnn_size)] * num_layers)
    
    with tf.variable_scope("decoding") as decoding_scope:
        output_fn = lambda x: tf.contrib.layers.fully_connected(x, vocab_size, None, scope=decoding_scope)
    with tf.variable_scope("decoding") as decoding_scope:    
        train_logits = decoding_layer_train(
            encoder_state, 
            dec_cell, 
            dec_embed_input, 
            sequence_length, 
            decoding_scope, 
            output_fn, 
            keep_prob
        )
    with tf.variable_scope("decoding", reuse=True) as decoding_scope:
        infer_logits = decoding_layer_infer(
            encoder_state, 
            dec_cell, 
            dec_embeddings, 
            target_vocab_to_int['<GO>'], 
            target_vocab_to_int['<EOS>'], 
            sequence_length-1, 
            vocab_size, 
            decoding_scope, 
            output_fn, 
            keep_prob
        )
    return train_logits, infer_logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Apply embedding to the input data for the encoder.
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob)`.
# - Process target data using your `process_decoding_input(target_data, target_vocab_to_int, batch_size)` function.
# - Apply embedding to the target data for the decoder.
# - Decode the encoded input using your `decoding_layer(dec_embed_input, dec_embeddings, encoder_state, vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)`.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size, sequence_length, source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size, rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param sequence_length: Sequence Length
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training Logits, Inference Logits)
    """
    embed_inputs = tf.contrib.layers.embed_sequence(input_data, source_vocab_size, enc_embedding_size)
    encoder_state = encoding_layer(embed_inputs, rnn_size, num_layers, keep_prob)
    
    dec_input = process_decoding_input(target_data, target_vocab_to_int, batch_size)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, dec_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    return decoding_layer(dec_embed_input, dec_embeddings, encoder_state, target_vocab_size, sequence_length, rnn_size, num_layers, target_vocab_to_int, keep_prob)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability

# %%
# Number of Epochs
epochs = 20
# Batch Size
batch_size = 2056
# RNN Size
rnn_size = 50
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 100
decoding_embedding_size = 100
# Learning Rate
learning_rate = 0.0075
# Dropout Keep Probability
keep_probability = 0.8

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_source_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob = model_inputs()
    sequence_length = tf.placeholder_with_default(max_source_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)
    
    train_logits, inference_logits = seq2seq_model(
        tf.reverse(input_data, [-1]), targets, keep_prob, batch_size, sequence_length, len(source_vocab_to_int), len(target_vocab_to_int),
        encoding_embedding_size, decoding_embedding_size, rnn_size, num_layers, target_vocab_to_int)

    tf.identity(inference_logits, 'logits')
    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            train_logits,
            targets,
            tf.ones([input_shape[0], sequence_length]))

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forums to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import time

def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1]), (0,0)],
            'constant')

    return np.mean(np.equal(target, np.argmax(logits, 2)))

train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]

valid_source = helper.pad_sentence_batch(source_int_text[:batch_size])
valid_target = helper.pad_sentence_batch(target_int_text[:batch_size])

with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch) in enumerate(
                helper.batch_data(train_source, train_target, batch_size)):
            start_time = time.time()
            
            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 sequence_length: target_batch.shape[1],
                 keep_prob: keep_probability})
            
            batch_train_logits = sess.run(
                inference_logits,
                {input_data: source_batch, keep_prob: 1.0})
            batch_valid_logits = sess.run(
                inference_logits,
                {input_data: valid_source, keep_prob: 1.0})
                
            train_acc = get_accuracy(target_batch, batch_train_logits)
            valid_acc = get_accuracy(np.array(valid_target), batch_valid_logits)
            end_time = time.time()
            print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.3f}, Validation Accuracy: {:>6.3f}, Loss: {:>6.3f}'
                  .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch    0/67 - Train Accuracy:  0.274, Validation Accuracy:  0.305, Loss:  5.883
# Epoch   0 Batch    1/67 - Train Accuracy:  0.273, Validation Accuracy:  0.305, Loss:  5.647
# Epoch   0 Batch    2/67 - Train Accuracy:  0.308, Validation Accuracy:  0.305, Loss:  5.322
# Epoch   0 Batch    3/67 - Train Accuracy:  0.268, Validation Accuracy:  0.305, Loss:  5.039
# Epoch   0 Batch    4/67 - Train Accuracy:  0.309, Validation Accuracy:  0.305, Loss:  4.603
# Epoch   0 Batch    5/67 - Train Accuracy:  0.323, Validation Accuracy:  0.316, Loss:  4.236
# Epoch   0 Batch    6/67 - Train Accuracy:  0.279, Validation Accuracy:  0.316, Loss:  4.018
# Epoch   0 Batch    7/67 - Train Accuracy:  0.306, Validation Accuracy:  0.335, Loss:  3.775
# Epoch   0 Batch    8/67 - Train Accuracy:  0.308, Validation Accuracy:  0.337, Loss:  3.624
# Epoch   0 Batch    9/67 - Train Accuracy:  0.341, Validation Accuracy:  0.339, Loss:  3.406
# Epoch   0 Batch   10/67 - Train Accuracy:  0.342, Validation Accuracy:  0.339, Loss:  3.333
# Epoch   0 Batch   11/67 - Train Accuracy:  0.314, Validation Accuracy:  0.339, Loss:  3.393
# Epoch   0 Batch   12/67 - Train Accuracy:  0.312, Validation Accuracy:  0.339, Loss:  3.359
# Epoch   0 Batch   13/67 - Train Accuracy:  0.312, Validation Accuracy:  0.339, Loss:  3.324
# Epoch   0 Batch   14/67 - Train Accuracy:  0.338, Validation Accuracy:  0.339, Loss:  3.168
# Epoch   0 Batch   15/67 - Train Accuracy:  0.338, Validation Accuracy:  0.339, Loss:  3.118
# Epoch   0 Batch   16/67 - Train Accuracy:  0.312, Validation Accuracy:  0.339, Loss:  3.203
# Epoch   0 Batch   17/67 - Train Accuracy:  0.343, Validation Accuracy:  0.339, Loss:  3.040
# Epoch   0 Batch   18/67 - Train Accuracy:  0.306, Validation Accuracy:  0.339, Loss:  3.140
# Epoch   0 Batch   19/67 - Train Accuracy:  0.316, Validation Accuracy:  0.339, Loss:  3.074
# Epoch   0 Batch   20/67 - Train Accuracy:  0.307, Validation Accuracy:  0.339, Loss:  3.063
# Epoch   0 Batch   21/67 - Train Accuracy:  0.310, Validation Accuracy:  0.339, Loss:  3.021
# Epoch   0 Batch   22/67 - Train Accuracy:  0.347, Validation Accuracy:  0.343, Loss:  2.869
# Epoch   0 Batch   23/67 - Train Accuracy:  0.337, Validation Accuracy:  0.362, Loss:  2.975
# Epoch   0 Batch   24/67 - Train Accuracy:  0.323, Validation Accuracy:  0.347, Loss:  2.937
# Epoch   0 Batch   25/67 - Train Accuracy:  0.336, Validation Accuracy:  0.365, Loss:  2.931
# Epoch   0 Batch   26/67 - Train Accuracy:  0.347, Validation Accuracy:  0.377, Loss:  2.922
# Epoch   0 Batch   27/67 - Train Accuracy:  0.382, Validation Accuracy:  0.380, Loss:  2.768
# Epoch   0 Batch   28/67 - Train Accuracy:  0.361, Validation Accuracy:  0.385, Loss:  2.851
# Epoch   0 Batch   29/67 - Train Accuracy:  0.363, Validation Accuracy:  0.387, Loss:  2.834
# Epoch   0 Batch   30/67 - Train Accuracy:  0.357, Validation Accuracy:  0.384, Loss:  2.808
# Epoch   0 Batch   31/67 - Train Accuracy:  0.362, Validation Accuracy:  0.388, Loss:  2.801
# Epoch   0 Batch   32/67 - Train Accuracy:  0.363, Validation Accuracy:  0.394, Loss:  2.787
# Epoch   0 Batch   33/67 - Train Accuracy:  0.338, Validation Accuracy:  0.397, Loss:  2.885
# Epoch   0 Batch   34/67 - Train Accuracy:  0.370, Validation Accuracy:  0.393, Loss:  2.724
# Epoch   0 Batch   35/67 - Train Accuracy:  0.406, Validation Accuracy:  0.405, Loss:  2.616
# Epoch   0 Batch   36/67 - Train Accuracy:  0.407, Validation Accuracy:  0.405, Loss:  2.597
# Epoch   0 Batch   37/67 - Train Accuracy:  0.388, Validation Accuracy:  0.416, Loss:  2.692
# Epoch   0 Batch   38/67 - Train Accuracy:  0.442, Validation Accuracy:  0.439, Loss:  2.541
# Epoch   0 Batch   39/67 - Train Accuracy:  0.414, Validation Accuracy:  0.440, Loss:  2.660
# Epoch   0 Batch   40/67 - Train Accuracy:  0.443, Validation Accuracy:  0.442, Loss:  2.510
# Epoch   0 Batch   41/67 - Train Accuracy:  0.426, Validation Accuracy:  0.453, Loss:  2.625
# Epoch   0 Batch   42/67 - Train Accuracy:  0.416, Validation Accuracy:  0.441, Loss:  2.611
# Epoch   0 Batch   43/67 - Train Accuracy:  0.448, Validation Accuracy:  0.447, Loss:  2.476
# Epoch   0 Batch   44/67 - Train Accuracy:  0.428, Validation Accuracy:  0.454, Loss:  2.570
# Epoch   0 Batch   45/67 - Train Accuracy:  0.498, Validation Accuracy:  0.447, Loss:  2.230
# Epoch   0 Batch   46/67 - Train Accuracy:  0.444, Validation Accuracy:  0.462, Loss:  2.511
# Epoch   0 Batch   47/67 - Train Accuracy:  0.435, Validation Accuracy:  0.459, Loss:  2.542
# Epoch   0 Batch   48/67 - Train Accuracy:  0.436, Validation Accuracy:  0.462, Loss:  2.530
# Epoch   0 Batch   49/67 - Train Accuracy:  0.435, Validation Accuracy:  0.455, Loss:  2.494
# Epoch   0 Batch   50/67 - Train Accuracy:  0.439, Validation Accuracy:  0.466, Loss:  2.504
# Epoch   0 Batch   51/67 - Train Accuracy:  0.470, Validation Accuracy:  0.466, Loss:  2.368
# Epoch   0 Batch   52/67 - Train Accuracy:  0.478, Validation Accuracy:  0.471, Loss:  2.330
# Epoch   0 Batch   53/67 - Train Accuracy:  0.450, Validation Accuracy:  0.471, Loss:  2.442
# Epoch   0 Batch   54/67 - Train Accuracy:  0.474, Validation Accuracy:  0.468, Loss:  2.314
# Epoch   0 Batch   55/67 - Train Accuracy:  0.472, Validation Accuracy:  0.467, Loss:  2.315
# Epoch   0 Batch   56/67 - Train Accuracy:  0.522, Validation Accuracy:  0.477, Loss:  2.139
# Epoch   0 Batch   57/67 - Train Accuracy:  0.455, Validation Accuracy:  0.479, Loss:  2.422
# Epoch   0 Batch   58/67 - Train Accuracy:  0.452, Validation Accuracy:  0.474, Loss:  2.388
# Epoch   0 Batch   59/67 - Train Accuracy:  0.498, Validation Accuracy:  0.471, Loss:  2.193
# Epoch   0 Batch   60/67 - Train Accuracy:  0.455, Validation Accuracy:  0.476, Loss:  2.392
# Epoch   0 Batch   61/67 - Train Accuracy:  0.485, Validation Accuracy:  0.478, Loss:  2.260
# Epoch   0 Batch   62/67 - Train Accuracy:  0.482, Validation Accuracy:  0.483, Loss:  2.272
# Epoch   0 Batch   63/67 - Train Accuracy:  0.440, Validation Accuracy:  0.469, Loss:  2.378
# Epoch   0 Batch   64/67 - Train Accuracy:  0.460, Validation Accuracy:  0.482, Loss:  2.371
# Epoch   0 Batch   65/67 - Train Accuracy:  0.455, Validation Accuracy:  0.479, Loss:  2.347
# Epoch   1 Batch    0/67 - Train Accuracy:  0.453, Validation Accuracy:  0.476, Loss:  2.310
# Epoch   1 Batch    1/67 - Train Accuracy:  0.466, Validation Accuracy:  0.486, Loss:  2.310
# Epoch   1 Batch    2/67 - Train Accuracy:  0.480, Validation Accuracy:  0.478, Loss:  2.210
# Epoch   1 Batch    3/67 - Train Accuracy:  0.460, Validation Accuracy:  0.486, Loss:  2.308
# Epoch   1 Batch    4/67 - Train Accuracy:  0.501, Validation Accuracy:  0.492, Loss:  2.178
# Epoch   1 Batch    5/67 - Train Accuracy:  0.485, Validation Accuracy:  0.480, Loss:  2.170
# Epoch   1 Batch    6/67 - Train Accuracy:  0.460, Validation Accuracy:  0.489, Loss:  2.304
# Epoch   1 Batch    7/67 - Train Accuracy:  0.468, Validation Accuracy:  0.490, Loss:  2.252
# Epoch   1 Batch    8/67 - Train Accuracy:  0.467, Validation Accuracy:  0.490, Loss:  2.254
# Epoch   1 Batch    9/67 - Train Accuracy:  0.494, Validation Accuracy:  0.493, Loss:  2.141
# Epoch   1 Batch   10/67 - Train Accuracy:  0.497, Validation Accuracy:  0.492, Loss:  2.125
# Epoch   1 Batch   11/67 - Train Accuracy:  0.473, Validation Accuracy:  0.492, Loss:  2.196
# Epoch   1 Batch   12/67 - Train Accuracy:  0.472, Validation Accuracy:  0.492, Loss:  2.204
# Epoch   1 Batch   13/67 - Train Accuracy:  0.480, Validation Accuracy:  0.499, Loss:  2.195
# Epoch   1 Batch   14/67 - Train Accuracy:  0.498, Validation Accuracy:  0.499, Loss:  2.100
# Epoch   1 Batch   15/67 - Train Accuracy:  0.494, Validation Accuracy:  0.494, Loss:  2.091
# Epoch   1 Batch   16/67 - Train Accuracy:  0.474, Validation Accuracy:  0.495, Loss:  2.183
# Epoch   1 Batch   17/67 - Train Accuracy:  0.504, Validation Accuracy:  0.501, Loss:  2.066
# Epoch   1 Batch   18/67 - Train Accuracy:  0.466, Validation Accuracy:  0.492, Loss:  2.178
# Epoch   1 Batch   19/67 - Train Accuracy:  0.476, Validation Accuracy:  0.492, Loss:  2.133
# Epoch   1 Batch   20/67 - Train Accuracy:  0.454, Validation Accuracy:  0.480, Loss:  2.185
# Epoch   1 Batch   21/67 - Train Accuracy:  0.479, Validation Accuracy:  0.503, Loss:  2.186
# Epoch   1 Batch   22/67 - Train Accuracy:  0.509, Validation Accuracy:  0.505, Loss:  2.041
# Epoch   1 Batch   23/67 - Train Accuracy:  0.471, Validation Accuracy:  0.495, Loss:  2.106
# Epoch   1 Batch   24/67 - Train Accuracy:  0.486, Validation Accuracy:  0.501, Loss:  2.117
# Epoch   1 Batch   25/67 - Train Accuracy:  0.480, Validation Accuracy:  0.505, Loss:  2.101
# Epoch   1 Batch   26/67 - Train Accuracy:  0.472, Validation Accuracy:  0.501, Loss:  2.086
# Epoch   1 Batch   27/67 - Train Accuracy:  0.501, Validation Accuracy:  0.501, Loss:  1.991
# Epoch   1 Batch   28/67 - Train Accuracy:  0.483, Validation Accuracy:  0.500, Loss:  2.053
# Epoch   1 Batch   29/67 - Train Accuracy:  0.471, Validation Accuracy:  0.492, Loss:  2.032
# Epoch   1 Batch   30/67 - Train Accuracy:  0.473, Validation Accuracy:  0.492, Loss:  2.042
# Epoch   1 Batch   31/67 - Train Accuracy:  0.476, Validation Accuracy:  0.498, Loss:  2.028
# Epoch   1 Batch   32/67 - Train Accuracy:  0.485, Validation Accuracy:  0.508, Loss:  2.013
# Epoch   1 Batch   33/67 - Train Accuracy:  0.458, Validation Accuracy:  0.503, Loss:  2.112
# Epoch   1 Batch   34/67 - Train Accuracy:  0.494, Validation Accuracy:  0.509, Loss:  1.979
# Epoch   1 Batch   35/67 - Train Accuracy:  0.508, Validation Accuracy:  0.510, Loss:  1.890
# Epoch   1 Batch   36/67 - Train Accuracy:  0.507, Validation Accuracy:  0.504, Loss:  1.900
# Epoch   1 Batch   37/67 - Train Accuracy:  0.490, Validation Accuracy:  0.512, Loss:  1.967
# Epoch   1 Batch   38/67 - Train Accuracy:  0.517, Validation Accuracy:  0.513, Loss:  1.840
# Epoch   1 Batch   39/67 - Train Accuracy:  0.485, Validation Accuracy:  0.507, Loss:  1.947
# Epoch   1 Batch   40/67 - Train Accuracy:  0.515, Validation Accuracy:  0.513, Loss:  1.835
# Epoch   1 Batch   41/67 - Train Accuracy:  0.491, Validation Accuracy:  0.513, Loss:  1.907
# Epoch   1 Batch   42/67 - Train Accuracy:  0.487, Validation Accuracy:  0.508, Loss:  1.902
# Epoch   1 Batch   43/67 - Train Accuracy:  0.518, Validation Accuracy:  0.516, Loss:  1.811
# Epoch   1 Batch   44/67 - Train Accuracy:  0.499, Validation Accuracy:  0.520, Loss:  1.873
# Epoch   1 Batch   45/67 - Train Accuracy:  0.558, Validation Accuracy:  0.513, Loss:  1.614
# Epoch   1 Batch   46/67 - Train Accuracy:  0.500, Validation Accuracy:  0.515, Loss:  1.826
# Epoch   1 Batch   47/67 - Train Accuracy:  0.495, Validation Accuracy:  0.513, Loss:  1.849
# Epoch   1 Batch   48/67 - Train Accuracy:  0.487, Validation Accuracy:  0.513, Loss:  1.838
# Epoch   1 Batch   49/67 - Train Accuracy:  0.496, Validation Accuracy:  0.515, Loss:  1.810
# Epoch   1 Batch   50/67 - Train Accuracy:  0.483, Validation Accuracy:  0.508, Loss:  1.811
# Epoch   1 Batch   51/67 - Train Accuracy:  0.515, Validation Accuracy:  0.512, Loss:  1.709
# Epoch   1 Batch   52/67 - Train Accuracy:  0.520, Validation Accuracy:  0.509, Loss:  1.681
# Epoch   1 Batch   53/67 - Train Accuracy:  0.496, Validation Accuracy:  0.515, Loss:  1.763
# Epoch   1 Batch   54/67 - Train Accuracy:  0.519, Validation Accuracy:  0.515, Loss:  1.656
# Epoch   1 Batch   55/67 - Train Accuracy:  0.516, Validation Accuracy:  0.510, Loss:  1.651
# Epoch   1 Batch   56/67 - Train Accuracy:  0.555, Validation Accuracy:  0.512, Loss:  1.524
# Epoch   1 Batch   57/67 - Train Accuracy:  0.494, Validation Accuracy:  0.516, Loss:  1.734
# Epoch   1 Batch   58/67 - Train Accuracy:  0.499, Validation Accuracy:  0.519, Loss:  1.702
# Epoch   1 Batch   59/67 - Train Accuracy:  0.537, Validation Accuracy:  0.514, Loss:  1.544
# Epoch   1 Batch   60/67 - Train Accuracy:  0.492, Validation Accuracy:  0.512, Loss:  1.681
# Epoch   1 Batch   61/67 - Train Accuracy:  0.517, Validation Accuracy:  0.510, Loss:  1.591
# Epoch   1 Batch   62/67 - Train Accuracy:  0.513, Validation Accuracy:  0.512, Loss:  1.603
# Epoch   1 Batch   63/67 - Train Accuracy:  0.484, Validation Accuracy:  0.509, Loss:  1.672
# Epoch   1 Batch   64/67 - Train Accuracy:  0.492, Validation Accuracy:  0.512, Loss:  1.650
# Epoch   1 Batch   65/67 - Train Accuracy:  0.487, Validation Accuracy:  0.506, Loss:  1.630
# Epoch   2 Batch    0/67 - Train Accuracy:  0.479, Validation Accuracy:  0.497, Loss:  1.610
# Epoch   2 Batch    1/67 - Train Accuracy:  0.485, Validation Accuracy:  0.505, Loss:  1.610
# Epoch   2 Batch    2/67 - Train Accuracy:  0.495, Validation Accuracy:  0.493, Loss:  1.532
# Epoch   2 Batch    3/67 - Train Accuracy:  0.452, Validation Accuracy:  0.482, Loss:  1.602
# Epoch   2 Batch    4/67 - Train Accuracy:  0.496, Validation Accuracy:  0.491, Loss:  1.514
# Epoch   2 Batch    5/67 - Train Accuracy:  0.493, Validation Accuracy:  0.492, Loss:  1.490
# Epoch   2 Batch    6/67 - Train Accuracy:  0.445, Validation Accuracy:  0.476, Loss:  1.572
# Epoch   2 Batch    7/67 - Train Accuracy:  0.463, Validation Accuracy:  0.486, Loss:  1.543
# Epoch   2 Batch    8/67 - Train Accuracy:  0.469, Validation Accuracy:  0.489, Loss:  1.556
# Epoch   2 Batch    9/67 - Train Accuracy:  0.486, Validation Accuracy:  0.486, Loss:  1.470
# Epoch   2 Batch   10/67 - Train Accuracy:  0.476, Validation Accuracy:  0.473, Loss:  1.446
# Epoch   2 Batch   11/67 - Train Accuracy:  0.459, Validation Accuracy:  0.480, Loss:  1.492
# Epoch   2 Batch   12/67 - Train Accuracy:  0.465, Validation Accuracy:  0.488, Loss:  1.508
# Epoch   2 Batch   13/67 - Train Accuracy:  0.455, Validation Accuracy:  0.479, Loss:  1.497
# Epoch   2 Batch   14/67 - Train Accuracy:  0.473, Validation Accuracy:  0.474, Loss:  1.415
# Epoch   2 Batch   15/67 - Train Accuracy:  0.486, Validation Accuracy:  0.489, Loss:  1.411
# Epoch   2 Batch   16/67 - Train Accuracy:  0.454, Validation Accuracy:  0.477, Loss:  1.471
# Epoch   2 Batch   17/67 - Train Accuracy:  0.481, Validation Accuracy:  0.479, Loss:  1.386
# Epoch   2 Batch   18/67 - Train Accuracy:  0.465, Validation Accuracy:  0.490, Loss:  1.451
# Epoch   2 Batch   19/67 - Train Accuracy:  0.477, Validation Accuracy:  0.492, Loss:  1.412
# Epoch   2 Batch   20/67 - Train Accuracy:  0.464, Validation Accuracy:  0.489, Loss:  1.420
# Epoch   2 Batch   21/67 - Train Accuracy:  0.471, Validation Accuracy:  0.493, Loss:  1.411
# Epoch   2 Batch   22/67 - Train Accuracy:  0.505, Validation Accuracy:  0.498, Loss:  1.337
# Epoch   2 Batch   23/67 - Train Accuracy:  0.491, Validation Accuracy:  0.509, Loss:  1.377
# Epoch   2 Batch   24/67 - Train Accuracy:  0.499, Validation Accuracy:  0.513, Loss:  1.358
# Epoch   2 Batch   25/67 - Train Accuracy:  0.498, Validation Accuracy:  0.521, Loss:  1.367
# Epoch   2 Batch   26/67 - Train Accuracy:  0.505, Validation Accuracy:  0.526, Loss:  1.352
# Epoch   2 Batch   27/67 - Train Accuracy:  0.526, Validation Accuracy:  0.523, Loss:  1.272
# Epoch   2 Batch   28/67 - Train Accuracy:  0.510, Validation Accuracy:  0.527, Loss:  1.316
# Epoch   2 Batch   29/67 - Train Accuracy:  0.513, Validation Accuracy:  0.533, Loss:  1.300
# Epoch   2 Batch   30/67 - Train Accuracy:  0.515, Validation Accuracy:  0.531, Loss:  1.284
# Epoch   2 Batch   31/67 - Train Accuracy:  0.526, Validation Accuracy:  0.542, Loss:  1.290
# Epoch   2 Batch   32/67 - Train Accuracy:  0.519, Validation Accuracy:  0.539, Loss:  1.275
# Epoch   2 Batch   33/67 - Train Accuracy:  0.490, Validation Accuracy:  0.528, Loss:  1.324
# Epoch   2 Batch   34/67 - Train Accuracy:  0.525, Validation Accuracy:  0.536, Loss:  1.238
# Epoch   2 Batch   35/67 - Train Accuracy:  0.529, Validation Accuracy:  0.525, Loss:  1.183
# Epoch   2 Batch   36/67 - Train Accuracy:  0.514, Validation Accuracy:  0.512, Loss:  1.185
# Epoch   2 Batch   37/67 - Train Accuracy:  0.495, Validation Accuracy:  0.518, Loss:  1.217
# Epoch   2 Batch   38/67 - Train Accuracy:  0.511, Validation Accuracy:  0.507, Loss:  1.147
# Epoch   2 Batch   39/67 - Train Accuracy:  0.481, Validation Accuracy:  0.509, Loss:  1.203
# Epoch   2 Batch   40/67 - Train Accuracy:  0.518, Validation Accuracy:  0.517, Loss:  1.127
# Epoch   2 Batch   41/67 - Train Accuracy:  0.487, Validation Accuracy:  0.512, Loss:  1.177
# Epoch   2 Batch   42/67 - Train Accuracy:  0.498, Validation Accuracy:  0.522, Loss:  1.169
# Epoch   2 Batch   43/67 - Train Accuracy:  0.506, Validation Accuracy:  0.511, Loss:  1.108
# Epoch   2 Batch   44/67 - Train Accuracy:  0.478, Validation Accuracy:  0.501, Loss:  1.148
# Epoch   2 Batch   45/67 - Train Accuracy:  0.545, Validation Accuracy:  0.500, Loss:  0.984
# Epoch   2 Batch   46/67 - Train Accuracy:  0.483, Validation Accuracy:  0.501, Loss:  1.110
# Epoch   2 Batch   47/67 - Train Accuracy:  0.475, Validation Accuracy:  0.499, Loss:  1.126
# Epoch   2 Batch   48/67 - Train Accuracy:  0.470, Validation Accuracy:  0.496, Loss:  1.120
# Epoch   2 Batch   49/67 - Train Accuracy:  0.468, Validation Accuracy:  0.493, Loss:  1.101
# Epoch   2 Batch   50/67 - Train Accuracy:  0.461, Validation Accuracy:  0.485, Loss:  1.098
# Epoch   2 Batch   51/67 - Train Accuracy:  0.492, Validation Accuracy:  0.489, Loss:  1.038
# Epoch   2 Batch   52/67 - Train Accuracy:  0.489, Validation Accuracy:  0.485, Loss:  1.021
# Epoch   2 Batch   53/67 - Train Accuracy:  0.457, Validation Accuracy:  0.477, Loss:  1.072
# Epoch   2 Batch   54/67 - Train Accuracy:  0.480, Validation Accuracy:  0.476, Loss:  1.004
# Epoch   2 Batch   55/67 - Train Accuracy:  0.478, Validation Accuracy:  0.472, Loss:  1.007
# Epoch   2 Batch   56/67 - Train Accuracy:  0.518, Validation Accuracy:  0.469, Loss:  0.925
# Epoch   2 Batch   57/67 - Train Accuracy:  0.445, Validation Accuracy:  0.473, Loss:  1.051
# Epoch   2 Batch   58/67 - Train Accuracy:  0.457, Validation Accuracy:  0.471, Loss:  1.035
# Epoch   2 Batch   59/67 - Train Accuracy:  0.504, Validation Accuracy:  0.472, Loss:  0.935
# Epoch   2 Batch   60/67 - Train Accuracy:  0.451, Validation Accuracy:  0.475, Loss:  1.025
# Epoch   2 Batch   61/67 - Train Accuracy:  0.489, Validation Accuracy:  0.481, Loss:  0.967
# Epoch   2 Batch   62/67 - Train Accuracy:  0.482, Validation Accuracy:  0.483, Loss:  0.973
# Epoch   2 Batch   63/67 - Train Accuracy:  0.462, Validation Accuracy:  0.483, Loss:  1.018
# Epoch   2 Batch   64/67 - Train Accuracy:  0.461, Validation Accuracy:  0.482, Loss:  1.008
# Epoch   2 Batch   65/67 - Train Accuracy:  0.464, Validation Accuracy:  0.484, Loss:  0.994
# Epoch   3 Batch    0/67 - Train Accuracy:  0.463, Validation Accuracy:  0.485, Loss:  0.982
# Epoch   3 Batch    1/67 - Train Accuracy:  0.462, Validation Accuracy:  0.489, Loss:  0.982
# Epoch   3 Batch    2/67 - Train Accuracy:  0.491, Validation Accuracy:  0.487, Loss:  0.933
# Epoch   3 Batch    3/67 - Train Accuracy:  0.464, Validation Accuracy:  0.488, Loss:  0.968
# Epoch   3 Batch    4/67 - Train Accuracy:  0.494, Validation Accuracy:  0.492, Loss:  0.924
# Epoch   3 Batch    5/67 - Train Accuracy:  0.500, Validation Accuracy:  0.490, Loss:  0.917
# Epoch   3 Batch    6/67 - Train Accuracy:  0.463, Validation Accuracy:  0.491, Loss:  0.959
# Epoch   3 Batch    7/67 - Train Accuracy:  0.475, Validation Accuracy:  0.493, Loss:  0.940
# Epoch   3 Batch    8/67 - Train Accuracy:  0.467, Validation Accuracy:  0.492, Loss:  0.952
# Epoch   3 Batch    9/67 - Train Accuracy:  0.474, Validation Accuracy:  0.479, Loss:  0.902
# Epoch   3 Batch   10/67 - Train Accuracy:  0.486, Validation Accuracy:  0.486, Loss:  0.893
# Epoch   3 Batch   11/67 - Train Accuracy:  0.477, Validation Accuracy:  0.492, Loss:  0.917
# Epoch   3 Batch   12/67 - Train Accuracy:  0.467, Validation Accuracy:  0.486, Loss:  0.920
# Epoch   3 Batch   13/67 - Train Accuracy:  0.469, Validation Accuracy:  0.489, Loss:  0.921
# Epoch   3 Batch   14/67 - Train Accuracy:  0.498, Validation Accuracy:  0.498, Loss:  0.872
# Epoch   3 Batch   15/67 - Train Accuracy:  0.498, Validation Accuracy:  0.495, Loss:  0.873
# Epoch   3 Batch   16/67 - Train Accuracy:  0.472, Validation Accuracy:  0.496, Loss:  0.921
# Epoch   3 Batch   17/67 - Train Accuracy:  0.496, Validation Accuracy:  0.495, Loss:  0.870
# Epoch   3 Batch   18/67 - Train Accuracy:  0.475, Validation Accuracy:  0.497, Loss:  0.907
# Epoch   3 Batch   19/67 - Train Accuracy:  0.495, Validation Accuracy:  0.501, Loss:  0.882
# Epoch   3 Batch   20/67 - Train Accuracy:  0.473, Validation Accuracy:  0.499, Loss:  0.890
# Epoch   3 Batch   21/67 - Train Accuracy:  0.480, Validation Accuracy:  0.501, Loss:  0.887
# Epoch   3 Batch   22/67 - Train Accuracy:  0.506, Validation Accuracy:  0.506, Loss:  0.842
# Epoch   3 Batch   23/67 - Train Accuracy:  0.475, Validation Accuracy:  0.497, Loss:  0.876
# Epoch   3 Batch   24/67 - Train Accuracy:  0.494, Validation Accuracy:  0.510, Loss:  0.865
# Epoch   3 Batch   25/67 - Train Accuracy:  0.482, Validation Accuracy:  0.505, Loss:  0.870
# Epoch   3 Batch   26/67 - Train Accuracy:  0.488, Validation Accuracy:  0.504, Loss:  0.868
# Epoch   3 Batch   27/67 - Train Accuracy:  0.512, Validation Accuracy:  0.504, Loss:  0.818
# Epoch   3 Batch   28/67 - Train Accuracy:  0.503, Validation Accuracy:  0.515, Loss:  0.848
# Epoch   3 Batch   29/67 - Train Accuracy:  0.507, Validation Accuracy:  0.525, Loss:  0.840
# Epoch   3 Batch   30/67 - Train Accuracy:  0.512, Validation Accuracy:  0.524, Loss:  0.831
# Epoch   3 Batch   31/67 - Train Accuracy:  0.521, Validation Accuracy:  0.536, Loss:  0.839
# Epoch   3 Batch   32/67 - Train Accuracy:  0.517, Validation Accuracy:  0.538, Loss:  0.832
# Epoch   3 Batch   33/67 - Train Accuracy:  0.537, Validation Accuracy:  0.564, Loss:  0.874
# Epoch   3 Batch   34/67 - Train Accuracy:  0.544, Validation Accuracy:  0.557, Loss:  0.819
# Epoch   3 Batch   35/67 - Train Accuracy:  0.576, Validation Accuracy:  0.569, Loss:  0.782
# Epoch   3 Batch   36/67 - Train Accuracy:  0.588, Validation Accuracy:  0.582, Loss:  0.790
# Epoch   3 Batch   37/67 - Train Accuracy:  0.560, Validation Accuracy:  0.576, Loss:  0.808
# Epoch   3 Batch   38/67 - Train Accuracy:  0.576, Validation Accuracy:  0.571, Loss:  0.772
# Epoch   3 Batch   39/67 - Train Accuracy:  0.560, Validation Accuracy:  0.578, Loss:  0.809
# Epoch   3 Batch   40/67 - Train Accuracy:  0.598, Validation Accuracy:  0.588, Loss:  0.759
# Epoch   3 Batch   41/67 - Train Accuracy:  0.574, Validation Accuracy:  0.583, Loss:  0.797
# Epoch   3 Batch   42/67 - Train Accuracy:  0.571, Validation Accuracy:  0.581, Loss:  0.794
# Epoch   3 Batch   43/67 - Train Accuracy:  0.590, Validation Accuracy:  0.581, Loss:  0.757
# Epoch   3 Batch   44/67 - Train Accuracy:  0.578, Validation Accuracy:  0.586, Loss:  0.786
# Epoch   3 Batch   45/67 - Train Accuracy:  0.638, Validation Accuracy:  0.594, Loss:  0.674
# Epoch   3 Batch   46/67 - Train Accuracy:  0.599, Validation Accuracy:  0.604, Loss:  0.759
# Epoch   3 Batch   47/67 - Train Accuracy:  0.590, Validation Accuracy:  0.591, Loss:  0.778
# Epoch   3 Batch   48/67 - Train Accuracy:  0.583, Validation Accuracy:  0.603, Loss:  0.773
# Epoch   3 Batch   49/67 - Train Accuracy:  0.590, Validation Accuracy:  0.603, Loss:  0.762
# Epoch   3 Batch   50/67 - Train Accuracy:  0.594, Validation Accuracy:  0.606, Loss:  0.757
# Epoch   3 Batch   51/67 - Train Accuracy:  0.614, Validation Accuracy:  0.606, Loss:  0.722
# Epoch   3 Batch   52/67 - Train Accuracy:  0.623, Validation Accuracy:  0.611, Loss:  0.714
# Epoch   3 Batch   53/67 - Train Accuracy:  0.591, Validation Accuracy:  0.599, Loss:  0.749
# Epoch   3 Batch   54/67 - Train Accuracy:  0.618, Validation Accuracy:  0.610, Loss:  0.701
# Epoch   3 Batch   55/67 - Train Accuracy:  0.613, Validation Accuracy:  0.602, Loss:  0.704
# Epoch   3 Batch   56/67 - Train Accuracy:  0.634, Validation Accuracy:  0.598, Loss:  0.647
# Epoch   3 Batch   57/67 - Train Accuracy:  0.592, Validation Accuracy:  0.605, Loss:  0.737
# Epoch   3 Batch   58/67 - Train Accuracy:  0.599, Validation Accuracy:  0.608, Loss:  0.725
# Epoch   3 Batch   59/67 - Train Accuracy:  0.635, Validation Accuracy:  0.611, Loss:  0.659
# Epoch   3 Batch   60/67 - Train Accuracy:  0.595, Validation Accuracy:  0.607, Loss:  0.725
# Epoch   3 Batch   61/67 - Train Accuracy:  0.638, Validation Accuracy:  0.625, Loss:  0.682
# Epoch   3 Batch   62/67 - Train Accuracy:  0.619, Validation Accuracy:  0.612, Loss:  0.690
# Epoch   3 Batch   63/67 - Train Accuracy:  0.610, Validation Accuracy:  0.628, Loss:  0.723
# Epoch   3 Batch   64/67 - Train Accuracy:  0.609, Validation Accuracy:  0.622, Loss:  0.712
# Epoch   3 Batch   65/67 - Train Accuracy:  0.605, Validation Accuracy:  0.613, Loss:  0.704
# Epoch   4 Batch    0/67 - Train Accuracy:  0.605, Validation Accuracy:  0.619, Loss:  0.696
# Epoch   4 Batch    1/67 - Train Accuracy:  0.608, Validation Accuracy:  0.619, Loss:  0.700
# Epoch   4 Batch    2/67 - Train Accuracy:  0.625, Validation Accuracy:  0.624, Loss:  0.666
# Epoch   4 Batch    3/67 - Train Accuracy:  0.616, Validation Accuracy:  0.630, Loss:  0.689
# Epoch   4 Batch    4/67 - Train Accuracy:  0.631, Validation Accuracy:  0.633, Loss:  0.658
# Epoch   4 Batch    5/67 - Train Accuracy:  0.635, Validation Accuracy:  0.627, Loss:  0.656
# Epoch   4 Batch    6/67 - Train Accuracy:  0.615, Validation Accuracy:  0.627, Loss:  0.684
# Epoch   4 Batch    7/67 - Train Accuracy:  0.624, Validation Accuracy:  0.637, Loss:  0.671
# Epoch   4 Batch    8/67 - Train Accuracy:  0.618, Validation Accuracy:  0.632, Loss:  0.684
# Epoch   4 Batch    9/67 - Train Accuracy:  0.630, Validation Accuracy:  0.631, Loss:  0.652
# Epoch   4 Batch   10/67 - Train Accuracy:  0.632, Validation Accuracy:  0.622, Loss:  0.645
# Epoch   4 Batch   11/67 - Train Accuracy:  0.622, Validation Accuracy:  0.633, Loss:  0.665
# Epoch   4 Batch   12/67 - Train Accuracy:  0.620, Validation Accuracy:  0.633, Loss:  0.667
# Epoch   4 Batch   13/67 - Train Accuracy:  0.625, Validation Accuracy:  0.628, Loss:  0.665
# Epoch   4 Batch   14/67 - Train Accuracy:  0.633, Validation Accuracy:  0.629, Loss:  0.631
# Epoch   4 Batch   15/67 - Train Accuracy:  0.632, Validation Accuracy:  0.631, Loss:  0.637
# Epoch   4 Batch   16/67 - Train Accuracy:  0.602, Validation Accuracy:  0.625, Loss:  0.671
# Epoch   4 Batch   17/67 - Train Accuracy:  0.634, Validation Accuracy:  0.631, Loss:  0.634
# Epoch   4 Batch   18/67 - Train Accuracy:  0.622, Validation Accuracy:  0.633, Loss:  0.658
# Epoch   4 Batch   19/67 - Train Accuracy:  0.634, Validation Accuracy:  0.638, Loss:  0.644
# Epoch   4 Batch   20/67 - Train Accuracy:  0.620, Validation Accuracy:  0.644, Loss:  0.649
# Epoch   4 Batch   21/67 - Train Accuracy:  0.625, Validation Accuracy:  0.652, Loss:  0.646
# Epoch   4 Batch   22/67 - Train Accuracy:  0.650, Validation Accuracy:  0.650, Loss:  0.616
# Epoch   4 Batch   23/67 - Train Accuracy:  0.639, Validation Accuracy:  0.651, Loss:  0.642
# Epoch   4 Batch   24/67 - Train Accuracy:  0.636, Validation Accuracy:  0.651, Loss:  0.636
# Epoch   4 Batch   25/67 - Train Accuracy:  0.631, Validation Accuracy:  0.653, Loss:  0.638
# Epoch   4 Batch   26/67 - Train Accuracy:  0.631, Validation Accuracy:  0.653, Loss:  0.639
# Epoch   4 Batch   27/67 - Train Accuracy:  0.647, Validation Accuracy:  0.650, Loss:  0.604
# Epoch   4 Batch   28/67 - Train Accuracy:  0.638, Validation Accuracy:  0.648, Loss:  0.629
# Epoch   4 Batch   29/67 - Train Accuracy:  0.637, Validation Accuracy:  0.649, Loss:  0.622
# Epoch   4 Batch   30/67 - Train Accuracy:  0.641, Validation Accuracy:  0.649, Loss:  0.619
# Epoch   4 Batch   31/67 - Train Accuracy:  0.629, Validation Accuracy:  0.654, Loss:  0.621
# Epoch   4 Batch   32/67 - Train Accuracy:  0.634, Validation Accuracy:  0.654, Loss:  0.618
# Epoch   4 Batch   33/67 - Train Accuracy:  0.616, Validation Accuracy:  0.647, Loss:  0.652
# Epoch   4 Batch   34/67 - Train Accuracy:  0.642, Validation Accuracy:  0.653, Loss:  0.612
# Epoch   4 Batch   35/67 - Train Accuracy:  0.657, Validation Accuracy:  0.662, Loss:  0.582
# Epoch   4 Batch   36/67 - Train Accuracy:  0.655, Validation Accuracy:  0.663, Loss:  0.594
# Epoch   4 Batch   37/67 - Train Accuracy:  0.648, Validation Accuracy:  0.663, Loss:  0.609
# Epoch   4 Batch   38/67 - Train Accuracy:  0.656, Validation Accuracy:  0.663, Loss:  0.581
# Epoch   4 Batch   39/67 - Train Accuracy:  0.642, Validation Accuracy:  0.666, Loss:  0.609
# Epoch   4 Batch   40/67 - Train Accuracy:  0.665, Validation Accuracy:  0.664, Loss:  0.574
# Epoch   4 Batch   41/67 - Train Accuracy:  0.646, Validation Accuracy:  0.658, Loss:  0.602
# Epoch   4 Batch   42/67 - Train Accuracy:  0.647, Validation Accuracy:  0.659, Loss:  0.600
# Epoch   4 Batch   43/67 - Train Accuracy:  0.657, Validation Accuracy:  0.661, Loss:  0.576
# Epoch   4 Batch   44/67 - Train Accuracy:  0.646, Validation Accuracy:  0.661, Loss:  0.599
# Epoch   4 Batch   45/67 - Train Accuracy:  0.699, Validation Accuracy:  0.663, Loss:  0.516
# Epoch   4 Batch   46/67 - Train Accuracy:  0.639, Validation Accuracy:  0.657, Loss:  0.582
# Epoch   4 Batch   47/67 - Train Accuracy:  0.651, Validation Accuracy:  0.664, Loss:  0.596
# Epoch   4 Batch   48/67 - Train Accuracy:  0.647, Validation Accuracy:  0.673, Loss:  0.593
# Epoch   4 Batch   49/67 - Train Accuracy:  0.658, Validation Accuracy:  0.672, Loss:  0.585
# Epoch   4 Batch   50/67 - Train Accuracy:  0.659, Validation Accuracy:  0.673, Loss:  0.582
# Epoch   4 Batch   51/67 - Train Accuracy:  0.684, Validation Accuracy:  0.677, Loss:  0.553
# Epoch   4 Batch   52/67 - Train Accuracy:  0.676, Validation Accuracy:  0.671, Loss:  0.553
# Epoch   4 Batch   53/67 - Train Accuracy:  0.658, Validation Accuracy:  0.667, Loss:  0.579
# Epoch   4 Batch   54/67 - Train Accuracy:  0.677, Validation Accuracy:  0.671, Loss:  0.543
# Epoch   4 Batch   55/67 - Train Accuracy:  0.676, Validation Accuracy:  0.670, Loss:  0.547
# Epoch   4 Batch   56/67 - Train Accuracy:  0.701, Validation Accuracy:  0.668, Loss:  0.502
# Epoch   4 Batch   57/67 - Train Accuracy:  0.661, Validation Accuracy:  0.677, Loss:  0.572
# Epoch   4 Batch   58/67 - Train Accuracy:  0.650, Validation Accuracy:  0.664, Loss:  0.564
# Epoch   4 Batch   59/67 - Train Accuracy:  0.687, Validation Accuracy:  0.666, Loss:  0.516
# Epoch   4 Batch   60/67 - Train Accuracy:  0.639, Validation Accuracy:  0.664, Loss:  0.572
# Epoch   4 Batch   61/67 - Train Accuracy:  0.677, Validation Accuracy:  0.665, Loss:  0.540
# Epoch   4 Batch   62/67 - Train Accuracy:  0.662, Validation Accuracy:  0.666, Loss:  0.553
# Epoch   4 Batch   63/67 - Train Accuracy:  0.661, Validation Accuracy:  0.683, Loss:  0.577
# Epoch   4 Batch   64/67 - Train Accuracy:  0.672, Validation Accuracy:  0.685, Loss:  0.562
# Epoch   4 Batch   65/67 - Train Accuracy:  0.665, Validation Accuracy:  0.677, Loss:  0.554
# Epoch   5 Batch    0/67 - Train Accuracy:  0.666, Validation Accuracy:  0.680, Loss:  0.553
# Epoch   5 Batch    1/67 - Train Accuracy:  0.675, Validation Accuracy:  0.679, Loss:  0.555
# Epoch   5 Batch    2/67 - Train Accuracy:  0.676, Validation Accuracy:  0.676, Loss:  0.530
# Epoch   5 Batch    3/67 - Train Accuracy:  0.671, Validation Accuracy:  0.684, Loss:  0.546
# Epoch   5 Batch    4/67 - Train Accuracy:  0.685, Validation Accuracy:  0.681, Loss:  0.521
# Epoch   5 Batch    5/67 - Train Accuracy:  0.692, Validation Accuracy:  0.683, Loss:  0.523
# Epoch   5 Batch    6/67 - Train Accuracy:  0.661, Validation Accuracy:  0.676, Loss:  0.543
# Epoch   5 Batch    7/67 - Train Accuracy:  0.675, Validation Accuracy:  0.686, Loss:  0.533
# Epoch   5 Batch    8/67 - Train Accuracy:  0.673, Validation Accuracy:  0.694, Loss:  0.544
# Epoch   5 Batch    9/67 - Train Accuracy:  0.685, Validation Accuracy:  0.687, Loss:  0.518
# Epoch   5 Batch   10/67 - Train Accuracy:  0.687, Validation Accuracy:  0.685, Loss:  0.510
# Epoch   5 Batch   11/67 - Train Accuracy:  0.679, Validation Accuracy:  0.692, Loss:  0.527
# Epoch   5 Batch   12/67 - Train Accuracy:  0.681, Validation Accuracy:  0.689, Loss:  0.528
# Epoch   5 Batch   13/67 - Train Accuracy:  0.674, Validation Accuracy:  0.683, Loss:  0.530
# Epoch   5 Batch   14/67 - Train Accuracy:  0.692, Validation Accuracy:  0.689, Loss:  0.502
# Epoch   5 Batch   15/67 - Train Accuracy:  0.692, Validation Accuracy:  0.693, Loss:  0.509
# Epoch   5 Batch   16/67 - Train Accuracy:  0.664, Validation Accuracy:  0.689, Loss:  0.538
# Epoch   5 Batch   17/67 - Train Accuracy:  0.690, Validation Accuracy:  0.690, Loss:  0.507
# Epoch   5 Batch   18/67 - Train Accuracy:  0.679, Validation Accuracy:  0.691, Loss:  0.525
# Epoch   5 Batch   19/67 - Train Accuracy:  0.690, Validation Accuracy:  0.693, Loss:  0.515
# Epoch   5 Batch   20/67 - Train Accuracy:  0.674, Validation Accuracy:  0.691, Loss:  0.519
# Epoch   5 Batch   21/67 - Train Accuracy:  0.676, Validation Accuracy:  0.691, Loss:  0.518
# Epoch   5 Batch   22/67 - Train Accuracy:  0.701, Validation Accuracy:  0.698, Loss:  0.494
# Epoch   5 Batch   23/67 - Train Accuracy:  0.685, Validation Accuracy:  0.697, Loss:  0.515
# Epoch   5 Batch   24/67 - Train Accuracy:  0.677, Validation Accuracy:  0.689, Loss:  0.512
# Epoch   5 Batch   25/67 - Train Accuracy:  0.677, Validation Accuracy:  0.696, Loss:  0.514
# Epoch   5 Batch   26/67 - Train Accuracy:  0.682, Validation Accuracy:  0.691, Loss:  0.515
# Epoch   5 Batch   27/67 - Train Accuracy:  0.696, Validation Accuracy:  0.694, Loss:  0.488
# Epoch   5 Batch   28/67 - Train Accuracy:  0.685, Validation Accuracy:  0.695, Loss:  0.509
# Epoch   5 Batch   29/67 - Train Accuracy:  0.682, Validation Accuracy:  0.696, Loss:  0.501
# Epoch   5 Batch   30/67 - Train Accuracy:  0.695, Validation Accuracy:  0.701, Loss:  0.499
# Epoch   5 Batch   31/67 - Train Accuracy:  0.676, Validation Accuracy:  0.699, Loss:  0.500
# Epoch   5 Batch   32/67 - Train Accuracy:  0.692, Validation Accuracy:  0.704, Loss:  0.500
# Epoch   5 Batch   33/67 - Train Accuracy:  0.670, Validation Accuracy:  0.697, Loss:  0.529
# Epoch   5 Batch   34/67 - Train Accuracy:  0.695, Validation Accuracy:  0.700, Loss:  0.495
# Epoch   5 Batch   35/67 - Train Accuracy:  0.701, Validation Accuracy:  0.703, Loss:  0.470
# Epoch   5 Batch   36/67 - Train Accuracy:  0.690, Validation Accuracy:  0.702, Loss:  0.481
# Epoch   5 Batch   37/67 - Train Accuracy:  0.696, Validation Accuracy:  0.698, Loss:  0.493
# Epoch   5 Batch   38/67 - Train Accuracy:  0.696, Validation Accuracy:  0.704, Loss:  0.471
# Epoch   5 Batch   39/67 - Train Accuracy:  0.685, Validation Accuracy:  0.704, Loss:  0.496
# Epoch   5 Batch   40/67 - Train Accuracy:  0.706, Validation Accuracy:  0.705, Loss:  0.466
# Epoch   5 Batch   41/67 - Train Accuracy:  0.692, Validation Accuracy:  0.704, Loss:  0.490
# Epoch   5 Batch   42/67 - Train Accuracy:  0.690, Validation Accuracy:  0.702, Loss:  0.490
# Epoch   5 Batch   43/67 - Train Accuracy:  0.700, Validation Accuracy:  0.703, Loss:  0.468
# Epoch   5 Batch   44/67 - Train Accuracy:  0.696, Validation Accuracy:  0.707, Loss:  0.487
# Epoch   5 Batch   45/67 - Train Accuracy:  0.731, Validation Accuracy:  0.704, Loss:  0.419
# Epoch   5 Batch   46/67 - Train Accuracy:  0.686, Validation Accuracy:  0.706, Loss:  0.475
# Epoch   5 Batch   47/67 - Train Accuracy:  0.697, Validation Accuracy:  0.708, Loss:  0.483
# Epoch   5 Batch   48/67 - Train Accuracy:  0.684, Validation Accuracy:  0.702, Loss:  0.485
# Epoch   5 Batch   49/67 - Train Accuracy:  0.698, Validation Accuracy:  0.708, Loss:  0.479
# Epoch   5 Batch   50/67 - Train Accuracy:  0.685, Validation Accuracy:  0.697, Loss:  0.481
# Epoch   5 Batch   51/67 - Train Accuracy:  0.719, Validation Accuracy:  0.704, Loss:  0.460
# Epoch   5 Batch   52/67 - Train Accuracy:  0.712, Validation Accuracy:  0.709, Loss:  0.460
# Epoch   5 Batch   53/67 - Train Accuracy:  0.686, Validation Accuracy:  0.697, Loss:  0.478
# Epoch   5 Batch   54/67 - Train Accuracy:  0.709, Validation Accuracy:  0.702, Loss:  0.452
# Epoch   5 Batch   55/67 - Train Accuracy:  0.712, Validation Accuracy:  0.708, Loss:  0.453
# Epoch   5 Batch   56/67 - Train Accuracy:  0.741, Validation Accuracy:  0.710, Loss:  0.413
# Epoch   5 Batch   57/67 - Train Accuracy:  0.690, Validation Accuracy:  0.705, Loss:  0.472
# Epoch   5 Batch   58/67 - Train Accuracy:  0.702, Validation Accuracy:  0.709, Loss:  0.466
# Epoch   5 Batch   59/67 - Train Accuracy:  0.741, Validation Accuracy:  0.714, Loss:  0.423
# Epoch   5 Batch   60/67 - Train Accuracy:  0.685, Validation Accuracy:  0.710, Loss:  0.465
# Epoch   5 Batch   61/67 - Train Accuracy:  0.729, Validation Accuracy:  0.714, Loss:  0.437
# Epoch   5 Batch   62/67 - Train Accuracy:  0.706, Validation Accuracy:  0.713, Loss:  0.450
# Epoch   5 Batch   63/67 - Train Accuracy:  0.693, Validation Accuracy:  0.717, Loss:  0.471
# Epoch   5 Batch   64/67 - Train Accuracy:  0.703, Validation Accuracy:  0.710, Loss:  0.459
# Epoch   5 Batch   65/67 - Train Accuracy:  0.702, Validation Accuracy:  0.716, Loss:  0.453
# Epoch   6 Batch    0/67 - Train Accuracy:  0.709, Validation Accuracy:  0.721, Loss:  0.452
# Epoch   6 Batch    1/67 - Train Accuracy:  0.705, Validation Accuracy:  0.717, Loss:  0.455
# Epoch   6 Batch    2/67 - Train Accuracy:  0.721, Validation Accuracy:  0.726, Loss:  0.437
# Epoch   6 Batch    3/67 - Train Accuracy:  0.707, Validation Accuracy:  0.723, Loss:  0.445
# Epoch   6 Batch    4/67 - Train Accuracy:  0.721, Validation Accuracy:  0.721, Loss:  0.427
# Epoch   6 Batch    5/67 - Train Accuracy:  0.734, Validation Accuracy:  0.725, Loss:  0.427
# Epoch   6 Batch    6/67 - Train Accuracy:  0.710, Validation Accuracy:  0.726, Loss:  0.447
# Epoch   6 Batch    7/67 - Train Accuracy:  0.715, Validation Accuracy:  0.725, Loss:  0.436
# Epoch   6 Batch    8/67 - Train Accuracy:  0.711, Validation Accuracy:  0.727, Loss:  0.444
# Epoch   6 Batch    9/67 - Train Accuracy:  0.724, Validation Accuracy:  0.724, Loss:  0.423
# Epoch   6 Batch   10/67 - Train Accuracy:  0.733, Validation Accuracy:  0.729, Loss:  0.419
# Epoch   6 Batch   11/67 - Train Accuracy:  0.723, Validation Accuracy:  0.735, Loss:  0.430
# Epoch   6 Batch   12/67 - Train Accuracy:  0.717, Validation Accuracy:  0.734, Loss:  0.432
# Epoch   6 Batch   13/67 - Train Accuracy:  0.728, Validation Accuracy:  0.737, Loss:  0.435
# Epoch   6 Batch   14/67 - Train Accuracy:  0.735, Validation Accuracy:  0.734, Loss:  0.409
# Epoch   6 Batch   15/67 - Train Accuracy:  0.729, Validation Accuracy:  0.736, Loss:  0.415
# Epoch   6 Batch   16/67 - Train Accuracy:  0.710, Validation Accuracy:  0.734, Loss:  0.441
# Epoch   6 Batch   17/67 - Train Accuracy:  0.732, Validation Accuracy:  0.736, Loss:  0.414
# Epoch   6 Batch   18/67 - Train Accuracy:  0.729, Validation Accuracy:  0.740, Loss:  0.429
# Epoch   6 Batch   19/67 - Train Accuracy:  0.723, Validation Accuracy:  0.732, Loss:  0.421
# Epoch   6 Batch   20/67 - Train Accuracy:  0.724, Validation Accuracy:  0.736, Loss:  0.427
# Epoch   6 Batch   21/67 - Train Accuracy:  0.703, Validation Accuracy:  0.724, Loss:  0.429
# Epoch   6 Batch   22/67 - Train Accuracy:  0.737, Validation Accuracy:  0.741, Loss:  0.413
# Epoch   6 Batch   23/67 - Train Accuracy:  0.724, Validation Accuracy:  0.739, Loss:  0.425
# Epoch   6 Batch   24/67 - Train Accuracy:  0.726, Validation Accuracy:  0.738, Loss:  0.417
# Epoch   6 Batch   25/67 - Train Accuracy:  0.727, Validation Accuracy:  0.745, Loss:  0.417
# Epoch   6 Batch   26/67 - Train Accuracy:  0.721, Validation Accuracy:  0.738, Loss:  0.423
# Epoch   6 Batch   27/67 - Train Accuracy:  0.738, Validation Accuracy:  0.740, Loss:  0.401
# Epoch   6 Batch   28/67 - Train Accuracy:  0.730, Validation Accuracy:  0.740, Loss:  0.416
# Epoch   6 Batch   29/67 - Train Accuracy:  0.712, Validation Accuracy:  0.737, Loss:  0.408
# Epoch   6 Batch   30/67 - Train Accuracy:  0.741, Validation Accuracy:  0.746, Loss:  0.411
# Epoch   6 Batch   31/67 - Train Accuracy:  0.729, Validation Accuracy:  0.746, Loss:  0.409
# Epoch   6 Batch   32/67 - Train Accuracy:  0.731, Validation Accuracy:  0.747, Loss:  0.407
# Epoch   6 Batch   33/67 - Train Accuracy:  0.724, Validation Accuracy:  0.750, Loss:  0.431
# Epoch   6 Batch   34/67 - Train Accuracy:  0.737, Validation Accuracy:  0.746, Loss:  0.404
# Epoch   6 Batch   35/67 - Train Accuracy:  0.745, Validation Accuracy:  0.746, Loss:  0.381
# Epoch   6 Batch   36/67 - Train Accuracy:  0.741, Validation Accuracy:  0.752, Loss:  0.391
# Epoch   6 Batch   37/67 - Train Accuracy:  0.743, Validation Accuracy:  0.750, Loss:  0.402
# Epoch   6 Batch   38/67 - Train Accuracy:  0.738, Validation Accuracy:  0.751, Loss:  0.381
# Epoch   6 Batch   39/67 - Train Accuracy:  0.736, Validation Accuracy:  0.751, Loss:  0.401
# Epoch   6 Batch   40/67 - Train Accuracy:  0.758, Validation Accuracy:  0.753, Loss:  0.378
# Epoch   6 Batch   41/67 - Train Accuracy:  0.742, Validation Accuracy:  0.756, Loss:  0.397
# Epoch   6 Batch   42/67 - Train Accuracy:  0.740, Validation Accuracy:  0.755, Loss:  0.397
# Epoch   6 Batch   43/67 - Train Accuracy:  0.745, Validation Accuracy:  0.749, Loss:  0.377
# Epoch   6 Batch   44/67 - Train Accuracy:  0.746, Validation Accuracy:  0.754, Loss:  0.394
# Epoch   6 Batch   45/67 - Train Accuracy:  0.784, Validation Accuracy:  0.756, Loss:  0.335
# Epoch   6 Batch   46/67 - Train Accuracy:  0.739, Validation Accuracy:  0.757, Loss:  0.382
# Epoch   6 Batch   47/67 - Train Accuracy:  0.750, Validation Accuracy:  0.758, Loss:  0.391
# Epoch   6 Batch   48/67 - Train Accuracy:  0.739, Validation Accuracy:  0.752, Loss:  0.388
# Epoch   6 Batch   49/67 - Train Accuracy:  0.741, Validation Accuracy:  0.758, Loss:  0.386
# Epoch   6 Batch   50/67 - Train Accuracy:  0.740, Validation Accuracy:  0.757, Loss:  0.386
# Epoch   6 Batch   51/67 - Train Accuracy:  0.765, Validation Accuracy:  0.764, Loss:  0.363
# Epoch   6 Batch   52/67 - Train Accuracy:  0.761, Validation Accuracy:  0.763, Loss:  0.364
# Epoch   6 Batch   53/67 - Train Accuracy:  0.751, Validation Accuracy:  0.760, Loss:  0.380
# Epoch   6 Batch   54/67 - Train Accuracy:  0.771, Validation Accuracy:  0.766, Loss:  0.357
# Epoch   6 Batch   55/67 - Train Accuracy:  0.765, Validation Accuracy:  0.763, Loss:  0.360
# Epoch   6 Batch   56/67 - Train Accuracy:  0.784, Validation Accuracy:  0.764, Loss:  0.330
# Epoch   6 Batch   57/67 - Train Accuracy:  0.754, Validation Accuracy:  0.767, Loss:  0.376
# Epoch   6 Batch   58/67 - Train Accuracy:  0.754, Validation Accuracy:  0.761, Loss:  0.368
# Epoch   6 Batch   59/67 - Train Accuracy:  0.786, Validation Accuracy:  0.768, Loss:  0.337
# Epoch   6 Batch   60/67 - Train Accuracy:  0.750, Validation Accuracy:  0.771, Loss:  0.372
# Epoch   6 Batch   61/67 - Train Accuracy:  0.778, Validation Accuracy:  0.772, Loss:  0.347
# Epoch   6 Batch   62/67 - Train Accuracy:  0.761, Validation Accuracy:  0.767, Loss:  0.357
# Epoch   6 Batch   63/67 - Train Accuracy:  0.750, Validation Accuracy:  0.770, Loss:  0.374
# Epoch   6 Batch   64/67 - Train Accuracy:  0.761, Validation Accuracy:  0.771, Loss:  0.367
# Epoch   6 Batch   65/67 - Train Accuracy:  0.747, Validation Accuracy:  0.759, Loss:  0.366
# Epoch   7 Batch    0/67 - Train Accuracy:  0.751, Validation Accuracy:  0.761, Loss:  0.368
# Epoch   7 Batch    1/67 - Train Accuracy:  0.744, Validation Accuracy:  0.748, Loss:  0.379
# Epoch   7 Batch    2/67 - Train Accuracy:  0.769, Validation Accuracy:  0.775, Loss:  0.361
# Epoch   7 Batch    3/67 - Train Accuracy:  0.741, Validation Accuracy:  0.756, Loss:  0.364
# Epoch   7 Batch    4/67 - Train Accuracy:  0.766, Validation Accuracy:  0.762, Loss:  0.352
# Epoch   7 Batch    5/67 - Train Accuracy:  0.773, Validation Accuracy:  0.770, Loss:  0.346
# Epoch   7 Batch    6/67 - Train Accuracy:  0.757, Validation Accuracy:  0.772, Loss:  0.364
# Epoch   7 Batch    7/67 - Train Accuracy:  0.762, Validation Accuracy:  0.771, Loss:  0.355
# Epoch   7 Batch    8/67 - Train Accuracy:  0.755, Validation Accuracy:  0.772, Loss:  0.360
# Epoch   7 Batch    9/67 - Train Accuracy:  0.763, Validation Accuracy:  0.769, Loss:  0.342
# Epoch   7 Batch   10/67 - Train Accuracy:  0.777, Validation Accuracy:  0.776, Loss:  0.338
# Epoch   7 Batch   11/67 - Train Accuracy:  0.773, Validation Accuracy:  0.780, Loss:  0.346
# Epoch   7 Batch   12/67 - Train Accuracy:  0.765, Validation Accuracy:  0.780, Loss:  0.346
# Epoch   7 Batch   13/67 - Train Accuracy:  0.767, Validation Accuracy:  0.780, Loss:  0.352
# Epoch   7 Batch   14/67 - Train Accuracy:  0.786, Validation Accuracy:  0.782, Loss:  0.327
# Epoch   7 Batch   15/67 - Train Accuracy:  0.780, Validation Accuracy:  0.787, Loss:  0.334
# Epoch   7 Batch   16/67 - Train Accuracy:  0.761, Validation Accuracy:  0.782, Loss:  0.355
# Epoch   7 Batch   17/67 - Train Accuracy:  0.782, Validation Accuracy:  0.786, Loss:  0.334
# Epoch   7 Batch   18/67 - Train Accuracy:  0.778, Validation Accuracy:  0.787, Loss:  0.344
# Epoch   7 Batch   19/67 - Train Accuracy:  0.777, Validation Accuracy:  0.786, Loss:  0.338
# Epoch   7 Batch   20/67 - Train Accuracy:  0.773, Validation Accuracy:  0.785, Loss:  0.342
# Epoch   7 Batch   21/67 - Train Accuracy:  0.776, Validation Accuracy:  0.787, Loss:  0.338
# Epoch   7 Batch   22/67 - Train Accuracy:  0.791, Validation Accuracy:  0.790, Loss:  0.327
# Epoch   7 Batch   23/67 - Train Accuracy:  0.760, Validation Accuracy:  0.774, Loss:  0.341
# Epoch   7 Batch   24/67 - Train Accuracy:  0.766, Validation Accuracy:  0.775, Loss:  0.349
# Epoch   7 Batch   25/67 - Train Accuracy:  0.742, Validation Accuracy:  0.765, Loss:  0.362
# Epoch   7 Batch   26/67 - Train Accuracy:  0.751, Validation Accuracy:  0.764, Loss:  0.356
# Epoch   7 Batch   27/67 - Train Accuracy:  0.779, Validation Accuracy:  0.782, Loss:  0.341
# Epoch   7 Batch   28/67 - Train Accuracy:  0.756, Validation Accuracy:  0.765, Loss:  0.346
# Epoch   7 Batch   29/67 - Train Accuracy:  0.769, Validation Accuracy:  0.786, Loss:  0.345
# Epoch   7 Batch   30/67 - Train Accuracy:  0.768, Validation Accuracy:  0.774, Loss:  0.338
# Epoch   7 Batch   31/67 - Train Accuracy:  0.744, Validation Accuracy:  0.764, Loss:  0.341
# Epoch   7 Batch   32/67 - Train Accuracy:  0.753, Validation Accuracy:  0.773, Loss:  0.339
# Epoch   7 Batch   33/67 - Train Accuracy:  0.769, Validation Accuracy:  0.789, Loss:  0.358
# Epoch   7 Batch   34/67 - Train Accuracy:  0.786, Validation Accuracy:  0.788, Loss:  0.334
# Epoch   7 Batch   35/67 - Train Accuracy:  0.781, Validation Accuracy:  0.782, Loss:  0.315
# Epoch   7 Batch   36/67 - Train Accuracy:  0.769, Validation Accuracy:  0.775, Loss:  0.323
# Epoch   7 Batch   37/67 - Train Accuracy:  0.782, Validation Accuracy:  0.791, Loss:  0.332
# Epoch   7 Batch   38/67 - Train Accuracy:  0.788, Validation Accuracy:  0.790, Loss:  0.313
# Epoch   7 Batch   39/67 - Train Accuracy:  0.791, Validation Accuracy:  0.799, Loss:  0.332
# Epoch   7 Batch   40/67 - Train Accuracy:  0.793, Validation Accuracy:  0.787, Loss:  0.306
# Epoch   7 Batch   41/67 - Train Accuracy:  0.779, Validation Accuracy:  0.792, Loss:  0.327
# Epoch   7 Batch   42/67 - Train Accuracy:  0.787, Validation Accuracy:  0.795, Loss:  0.324
# Epoch   7 Batch   43/67 - Train Accuracy:  0.797, Validation Accuracy:  0.795, Loss:  0.311
# Epoch   7 Batch   44/67 - Train Accuracy:  0.780, Validation Accuracy:  0.795, Loss:  0.322
# Epoch   7 Batch   45/67 - Train Accuracy:  0.817, Validation Accuracy:  0.795, Loss:  0.270
# Epoch   7 Batch   46/67 - Train Accuracy:  0.790, Validation Accuracy:  0.801, Loss:  0.310
# Epoch   7 Batch   47/67 - Train Accuracy:  0.794, Validation Accuracy:  0.804, Loss:  0.319
# Epoch   7 Batch   48/67 - Train Accuracy:  0.794, Validation Accuracy:  0.804, Loss:  0.316
# Epoch   7 Batch   49/67 - Train Accuracy:  0.795, Validation Accuracy:  0.800, Loss:  0.314
# Epoch   7 Batch   50/67 - Train Accuracy:  0.793, Validation Accuracy:  0.803, Loss:  0.313
# Epoch   7 Batch   51/67 - Train Accuracy:  0.809, Validation Accuracy:  0.805, Loss:  0.293
# Epoch   7 Batch   52/67 - Train Accuracy:  0.812, Validation Accuracy:  0.808, Loss:  0.297
# Epoch   7 Batch   53/67 - Train Accuracy:  0.800, Validation Accuracy:  0.808, Loss:  0.309
# Epoch   7 Batch   54/67 - Train Accuracy:  0.810, Validation Accuracy:  0.802, Loss:  0.291
# Epoch   7 Batch   55/67 - Train Accuracy:  0.803, Validation Accuracy:  0.803, Loss:  0.292
# Epoch   7 Batch   56/67 - Train Accuracy:  0.823, Validation Accuracy:  0.807, Loss:  0.268
# Epoch   7 Batch   57/67 - Train Accuracy:  0.800, Validation Accuracy:  0.808, Loss:  0.303
# Epoch   7 Batch   58/67 - Train Accuracy:  0.797, Validation Accuracy:  0.804, Loss:  0.298
# ...
# Epoch  17 Batch   25/67 - Train Accuracy:  0.932, Validation Accuracy:  0.925, Loss:  0.056
# Epoch  17 Batch   26/67 - Train Accuracy:  0.923, Validation Accuracy:  0.931, Loss:  0.059
# Epoch  17 Batch   27/67 - Train Accuracy:  0.923, Validation Accuracy:  0.932, Loss:  0.056
# Epoch  17 Batch   28/67 - Train Accuracy:  0.926, Validation Accuracy:  0.933, Loss:  0.058
# Epoch  17 Batch   29/67 - Train Accuracy:  0.928, Validation Accuracy:  0.934, Loss:  0.056
# Epoch  17 Batch   30/67 - Train Accuracy:  0.924, Validation Accuracy:  0.936, Loss:  0.054
# Epoch  17 Batch   31/67 - Train Accuracy:  0.925, Validation Accuracy:  0.931, Loss:  0.055
# Epoch  17 Batch   32/67 - Train Accuracy:  0.929, Validation Accuracy:  0.933, Loss:  0.055
# Epoch  17 Batch   33/67 - Train Accuracy:  0.919, Validation Accuracy:  0.933, Loss:  0.058
# Epoch  17 Batch   34/67 - Train Accuracy:  0.926, Validation Accuracy:  0.932, Loss:  0.058
# Epoch  17 Batch   35/67 - Train Accuracy:  0.934, Validation Accuracy:  0.935, Loss:  0.051
# Epoch  17 Batch   36/67 - Train Accuracy:  0.925, Validation Accuracy:  0.933, Loss:  0.057
# Epoch  17 Batch   37/67 - Train Accuracy:  0.934, Validation Accuracy:  0.934, Loss:  0.056
# Epoch  17 Batch   38/67 - Train Accuracy:  0.928, Validation Accuracy:  0.930, Loss:  0.053
# Epoch  17 Batch   39/67 - Train Accuracy:  0.929, Validation Accuracy:  0.934, Loss:  0.056
# Epoch  17 Batch   40/67 - Train Accuracy:  0.934, Validation Accuracy:  0.934, Loss:  0.052
# Epoch  17 Batch   41/67 - Train Accuracy:  0.931, Validation Accuracy:  0.930, Loss:  0.053
# Epoch  17 Batch   42/67 - Train Accuracy:  0.928, Validation Accuracy:  0.932, Loss:  0.058
# Epoch  17 Batch   43/67 - Train Accuracy:  0.926, Validation Accuracy:  0.934, Loss:  0.055
# Epoch  17 Batch   44/67 - Train Accuracy:  0.928, Validation Accuracy:  0.931, Loss:  0.056
# Epoch  17 Batch   45/67 - Train Accuracy:  0.940, Validation Accuracy:  0.929, Loss:  0.045
# Epoch  17 Batch   46/67 - Train Accuracy:  0.927, Validation Accuracy:  0.937, Loss:  0.054
# Epoch  17 Batch   47/67 - Train Accuracy:  0.928, Validation Accuracy:  0.937, Loss:  0.054
# Epoch  17 Batch   48/67 - Train Accuracy:  0.924, Validation Accuracy:  0.935, Loss:  0.055
# Epoch  17 Batch   49/67 - Train Accuracy:  0.929, Validation Accuracy:  0.934, Loss:  0.054
# Epoch  17 Batch   50/67 - Train Accuracy:  0.925, Validation Accuracy:  0.934, Loss:  0.054
# Epoch  17 Batch   51/67 - Train Accuracy:  0.929, Validation Accuracy:  0.929, Loss:  0.052
# Epoch  17 Batch   52/67 - Train Accuracy:  0.926, Validation Accuracy:  0.928, Loss:  0.055
# Epoch  17 Batch   53/67 - Train Accuracy:  0.929, Validation Accuracy:  0.935, Loss:  0.056
# Epoch  17 Batch   54/67 - Train Accuracy:  0.930, Validation Accuracy:  0.934, Loss:  0.053
# Epoch  17 Batch   55/67 - Train Accuracy:  0.930, Validation Accuracy:  0.935, Loss:  0.056
# Epoch  17 Batch   56/67 - Train Accuracy:  0.934, Validation Accuracy:  0.933, Loss:  0.048
# Epoch  17 Batch   57/67 - Train Accuracy:  0.934, Validation Accuracy:  0.934, Loss:  0.052
# Epoch  17 Batch   58/67 - Train Accuracy:  0.930, Validation Accuracy:  0.935, Loss:  0.053
# Epoch  17 Batch   59/67 - Train Accuracy:  0.935, Validation Accuracy:  0.934, Loss:  0.049
# Epoch  17 Batch   60/67 - Train Accuracy:  0.927, Validation Accuracy:  0.935, Loss:  0.054
# Epoch  17 Batch   61/67 - Train Accuracy:  0.937, Validation Accuracy:  0.934, Loss:  0.050
# Epoch  17 Batch   62/67 - Train Accuracy:  0.932, Validation Accuracy:  0.936, Loss:  0.052
# Epoch  17 Batch   63/67 - Train Accuracy:  0.921, Validation Accuracy:  0.936, Loss:  0.056
# Epoch  17 Batch   64/67 - Train Accuracy:  0.930, Validation Accuracy:  0.937, Loss:  0.054
# Epoch  17 Batch   65/67 - Train Accuracy:  0.928, Validation Accuracy:  0.928, Loss:  0.053
# Epoch  18 Batch    0/67 - Train Accuracy:  0.926, Validation Accuracy:  0.932, Loss:  0.053
# Epoch  18 Batch    1/67 - Train Accuracy:  0.927, Validation Accuracy:  0.936, Loss:  0.054
# Epoch  18 Batch    2/67 - Train Accuracy:  0.929, Validation Accuracy:  0.932, Loss:  0.053
# Epoch  18 Batch    3/67 - Train Accuracy:  0.928, Validation Accuracy:  0.932, Loss:  0.051
# Epoch  18 Batch    4/67 - Train Accuracy:  0.939, Validation Accuracy:  0.935, Loss:  0.050
# Epoch  18 Batch    5/67 - Train Accuracy:  0.929, Validation Accuracy:  0.930, Loss:  0.053
# Epoch  18 Batch    6/67 - Train Accuracy:  0.926, Validation Accuracy:  0.937, Loss:  0.054
# Epoch  18 Batch    7/67 - Train Accuracy:  0.931, Validation Accuracy:  0.933, Loss:  0.050
# Epoch  18 Batch    8/67 - Train Accuracy:  0.920, Validation Accuracy:  0.934, Loss:  0.058
# Epoch  18 Batch    9/67 - Train Accuracy:  0.935, Validation Accuracy:  0.937, Loss:  0.052
# Epoch  18 Batch   10/67 - Train Accuracy:  0.936, Validation Accuracy:  0.934, Loss:  0.049
# Epoch  18 Batch   11/67 - Train Accuracy:  0.933, Validation Accuracy:  0.932, Loss:  0.052
# Epoch  18 Batch   12/67 - Train Accuracy:  0.931, Validation Accuracy:  0.933, Loss:  0.049
# Epoch  18 Batch   13/67 - Train Accuracy:  0.923, Validation Accuracy:  0.934, Loss:  0.053
# Epoch  18 Batch   14/67 - Train Accuracy:  0.930, Validation Accuracy:  0.935, Loss:  0.048
# Epoch  18 Batch   15/67 - Train Accuracy:  0.929, Validation Accuracy:  0.932, Loss:  0.052
# Epoch  18 Batch   16/67 - Train Accuracy:  0.924, Validation Accuracy:  0.936, Loss:  0.058
# Epoch  18 Batch   17/67 - Train Accuracy:  0.931, Validation Accuracy:  0.932, Loss:  0.054
# Epoch  18 Batch   18/67 - Train Accuracy:  0.929, Validation Accuracy:  0.929, Loss:  0.054
# Epoch  18 Batch   19/67 - Train Accuracy:  0.929, Validation Accuracy:  0.933, Loss:  0.053
# Epoch  18 Batch   20/67 - Train Accuracy:  0.925, Validation Accuracy:  0.934, Loss:  0.054
# Epoch  18 Batch   21/67 - Train Accuracy:  0.933, Validation Accuracy:  0.930, Loss:  0.052
# Epoch  18 Batch   22/67 - Train Accuracy:  0.937, Validation Accuracy:  0.933, Loss:  0.049
# Epoch  18 Batch   23/67 - Train Accuracy:  0.926, Validation Accuracy:  0.932, Loss:  0.052
# Epoch  18 Batch   24/67 - Train Accuracy:  0.932, Validation Accuracy:  0.936, Loss:  0.052
# Epoch  18 Batch   25/67 - Train Accuracy:  0.933, Validation Accuracy:  0.928, Loss:  0.050
# Epoch  18 Batch   26/67 - Train Accuracy:  0.927, Validation Accuracy:  0.934, Loss:  0.053
# Epoch  18 Batch   27/67 - Train Accuracy:  0.924, Validation Accuracy:  0.933, Loss:  0.050
# Epoch  18 Batch   28/67 - Train Accuracy:  0.929, Validation Accuracy:  0.936, Loss:  0.053
# Epoch  18 Batch   29/67 - Train Accuracy:  0.925, Validation Accuracy:  0.932, Loss:  0.050
# Epoch  18 Batch   30/67 - Train Accuracy:  0.926, Validation Accuracy:  0.938, Loss:  0.050
# Epoch  18 Batch   31/67 - Train Accuracy:  0.928, Validation Accuracy:  0.934, Loss:  0.050
# Epoch  18 Batch   32/67 - Train Accuracy:  0.930, Validation Accuracy:  0.938, Loss:  0.051
# Epoch  18 Batch   33/67 - Train Accuracy:  0.926, Validation Accuracy:  0.938, Loss:  0.052
# Epoch  18 Batch   34/67 - Train Accuracy:  0.928, Validation Accuracy:  0.937, Loss:  0.052
# Epoch  18 Batch   35/67 - Train Accuracy:  0.937, Validation Accuracy:  0.937, Loss:  0.046
# Epoch  18 Batch   36/67 - Train Accuracy:  0.933, Validation Accuracy:  0.935, Loss:  0.052
# Epoch  18 Batch   37/67 - Train Accuracy:  0.933, Validation Accuracy:  0.935, Loss:  0.051
# Epoch  18 Batch   38/67 - Train Accuracy:  0.932, Validation Accuracy:  0.935, Loss:  0.049
# Epoch  18 Batch   39/67 - Train Accuracy:  0.932, Validation Accuracy:  0.933, Loss:  0.050
# Epoch  18 Batch   40/67 - Train Accuracy:  0.936, Validation Accuracy:  0.936, Loss:  0.047
# Epoch  18 Batch   41/67 - Train Accuracy:  0.931, Validation Accuracy:  0.935, Loss:  0.047
# Epoch  18 Batch   42/67 - Train Accuracy:  0.930, Validation Accuracy:  0.933, Loss:  0.053
# Epoch  18 Batch   43/67 - Train Accuracy:  0.932, Validation Accuracy:  0.935, Loss:  0.050
# Epoch  18 Batch   44/67 - Train Accuracy:  0.929, Validation Accuracy:  0.939, Loss:  0.050
# Epoch  18 Batch   45/67 - Train Accuracy:  0.945, Validation Accuracy:  0.937, Loss:  0.040
# Epoch  18 Batch   46/67 - Train Accuracy:  0.931, Validation Accuracy:  0.933, Loss:  0.048
# Epoch  18 Batch   47/67 - Train Accuracy:  0.930, Validation Accuracy:  0.936, Loss:  0.049
# Epoch  18 Batch   48/67 - Train Accuracy:  0.929, Validation Accuracy:  0.940, Loss:  0.049
# Epoch  18 Batch   49/67 - Train Accuracy:  0.933, Validation Accuracy:  0.936, Loss:  0.049
# Epoch  18 Batch   50/67 - Train Accuracy:  0.928, Validation Accuracy:  0.933, Loss:  0.049
# Epoch  18 Batch   51/67 - Train Accuracy:  0.932, Validation Accuracy:  0.935, Loss:  0.047
# Epoch  18 Batch   52/67 - Train Accuracy:  0.930, Validation Accuracy:  0.933, Loss:  0.050
# Epoch  18 Batch   53/67 - Train Accuracy:  0.932, Validation Accuracy:  0.939, Loss:  0.051
# Epoch  18 Batch   54/67 - Train Accuracy:  0.933, Validation Accuracy:  0.939, Loss:  0.048
# Epoch  18 Batch   55/67 - Train Accuracy:  0.936, Validation Accuracy:  0.939, Loss:  0.051
# Epoch  18 Batch   56/67 - Train Accuracy:  0.937, Validation Accuracy:  0.936, Loss:  0.044
# Epoch  18 Batch   57/67 - Train Accuracy:  0.938, Validation Accuracy:  0.932, Loss:  0.048
# Epoch  18 Batch   58/67 - Train Accuracy:  0.932, Validation Accuracy:  0.940, Loss:  0.049
# Epoch  18 Batch   59/67 - Train Accuracy:  0.938, Validation Accuracy:  0.933, Loss:  0.045
# Epoch  18 Batch   60/67 - Train Accuracy:  0.931, Validation Accuracy:  0.936, Loss:  0.050
# Epoch  18 Batch   61/67 - Train Accuracy:  0.939, Validation Accuracy:  0.935, Loss:  0.045
# Epoch  18 Batch   62/67 - Train Accuracy:  0.934, Validation Accuracy:  0.939, Loss:  0.047
# Epoch  18 Batch   63/67 - Train Accuracy:  0.925, Validation Accuracy:  0.935, Loss:  0.051
# Epoch  18 Batch   64/67 - Train Accuracy:  0.932, Validation Accuracy:  0.939, Loss:  0.049
# Epoch  18 Batch   65/67 - Train Accuracy:  0.932, Validation Accuracy:  0.931, Loss:  0.049
# Epoch  19 Batch    0/67 - Train Accuracy:  0.933, Validation Accuracy:  0.937, Loss:  0.048
# Epoch  19 Batch    1/67 - Train Accuracy:  0.930, Validation Accuracy:  0.940, Loss:  0.050
# Epoch  19 Batch    2/67 - Train Accuracy:  0.932, Validation Accuracy:  0.935, Loss:  0.048
# Epoch  19 Batch    3/67 - Train Accuracy:  0.931, Validation Accuracy:  0.936, Loss:  0.046
# Epoch  19 Batch    4/67 - Train Accuracy:  0.940, Validation Accuracy:  0.937, Loss:  0.046
# Epoch  19 Batch    5/67 - Train Accuracy:  0.931, Validation Accuracy:  0.932, Loss:  0.049
# Epoch  19 Batch    6/67 - Train Accuracy:  0.926, Validation Accuracy:  0.937, Loss:  0.049
# Epoch  19 Batch    7/67 - Train Accuracy:  0.934, Validation Accuracy:  0.937, Loss:  0.046
# Epoch  19 Batch    8/67 - Train Accuracy:  0.923, Validation Accuracy:  0.935, Loss:  0.053
# Epoch  19 Batch    9/67 - Train Accuracy:  0.936, Validation Accuracy:  0.936, Loss:  0.048
# Epoch  19 Batch   10/67 - Train Accuracy:  0.938, Validation Accuracy:  0.937, Loss:  0.045
# Epoch  19 Batch   11/67 - Train Accuracy:  0.936, Validation Accuracy:  0.937, Loss:  0.048
# Epoch  19 Batch   12/67 - Train Accuracy:  0.936, Validation Accuracy:  0.936, Loss:  0.045
# Epoch  19 Batch   13/67 - Train Accuracy:  0.928, Validation Accuracy:  0.936, Loss:  0.048
# Epoch  19 Batch   14/67 - Train Accuracy:  0.935, Validation Accuracy:  0.934, Loss:  0.043
# Epoch  19 Batch   15/67 - Train Accuracy:  0.931, Validation Accuracy:  0.934, Loss:  0.047
# Epoch  19 Batch   16/67 - Train Accuracy:  0.926, Validation Accuracy:  0.937, Loss:  0.053
# Epoch  19 Batch   17/67 - Train Accuracy:  0.935, Validation Accuracy:  0.934, Loss:  0.049
# Epoch  19 Batch   18/67 - Train Accuracy:  0.933, Validation Accuracy:  0.930, Loss:  0.050
# Epoch  19 Batch   19/67 - Train Accuracy:  0.932, Validation Accuracy:  0.935, Loss:  0.048
# Epoch  19 Batch   20/67 - Train Accuracy:  0.926, Validation Accuracy:  0.935, Loss:  0.048
# Epoch  19 Batch   21/67 - Train Accuracy:  0.937, Validation Accuracy:  0.935, Loss:  0.047
# Epoch  19 Batch   22/67 - Train Accuracy:  0.938, Validation Accuracy:  0.932, Loss:  0.045
# Epoch  19 Batch   23/67 - Train Accuracy:  0.935, Validation Accuracy:  0.938, Loss:  0.048
# Epoch  19 Batch   24/67 - Train Accuracy:  0.937, Validation Accuracy:  0.940, Loss:  0.047
# Epoch  19 Batch   25/67 - Train Accuracy:  0.940, Validation Accuracy:  0.935, Loss:  0.046
# Epoch  19 Batch   26/67 - Train Accuracy:  0.930, Validation Accuracy:  0.932, Loss:  0.048
# Epoch  19 Batch   27/67 - Train Accuracy:  0.932, Validation Accuracy:  0.938, Loss:  0.046
# Epoch  19 Batch   28/67 - Train Accuracy:  0.930, Validation Accuracy:  0.940, Loss:  0.048
# Epoch  19 Batch   29/67 - Train Accuracy:  0.928, Validation Accuracy:  0.938, Loss:  0.046
# Epoch  19 Batch   30/67 - Train Accuracy:  0.932, Validation Accuracy:  0.937, Loss:  0.044
# Epoch  19 Batch   31/67 - Train Accuracy:  0.935, Validation Accuracy:  0.939, Loss:  0.045
# Epoch  19 Batch   32/67 - Train Accuracy:  0.935, Validation Accuracy:  0.940, Loss:  0.045
# Epoch  19 Batch   33/67 - Train Accuracy:  0.926, Validation Accuracy:  0.940, Loss:  0.048
# Epoch  19 Batch   34/67 - Train Accuracy:  0.933, Validation Accuracy:  0.940, Loss:  0.048
# Epoch  19 Batch   35/67 - Train Accuracy:  0.942, Validation Accuracy:  0.940, Loss:  0.041
# Epoch  19 Batch   36/67 - Train Accuracy:  0.938, Validation Accuracy:  0.941, Loss:  0.047
# Epoch  19 Batch   37/67 - Train Accuracy:  0.940, Validation Accuracy:  0.942, Loss:  0.045
# Epoch  19 Batch   38/67 - Train Accuracy:  0.935, Validation Accuracy:  0.940, Loss:  0.044
# Epoch  19 Batch   39/67 - Train Accuracy:  0.938, Validation Accuracy:  0.938, Loss:  0.046
# Epoch  19 Batch   40/67 - Train Accuracy:  0.943, Validation Accuracy:  0.941, Loss:  0.043
# Epoch  19 Batch   41/67 - Train Accuracy:  0.933, Validation Accuracy:  0.939, Loss:  0.043
# Epoch  19 Batch   42/67 - Train Accuracy:  0.937, Validation Accuracy:  0.937, Loss:  0.047
# Epoch  19 Batch   43/67 - Train Accuracy:  0.935, Validation Accuracy:  0.938, Loss:  0.046
# Epoch  19 Batch   44/67 - Train Accuracy:  0.932, Validation Accuracy:  0.940, Loss:  0.046
# Epoch  19 Batch   45/67 - Train Accuracy:  0.949, Validation Accuracy:  0.940, Loss:  0.037
# Epoch  19 Batch   46/67 - Train Accuracy:  0.936, Validation Accuracy:  0.938, Loss:  0.044
# Epoch  19 Batch   47/67 - Train Accuracy:  0.933, Validation Accuracy:  0.943, Loss:  0.044
# Epoch  19 Batch   48/67 - Train Accuracy:  0.935, Validation Accuracy:  0.942, Loss:  0.044
# Epoch  19 Batch   49/67 - Train Accuracy:  0.938, Validation Accuracy:  0.938, Loss:  0.044
# Epoch  19 Batch   50/67 - Train Accuracy:  0.933, Validation Accuracy:  0.936, Loss:  0.044
# Epoch  19 Batch   51/67 - Train Accuracy:  0.936, Validation Accuracy:  0.937, Loss:  0.043
# Epoch  19 Batch   52/67 - Train Accuracy:  0.935, Validation Accuracy:  0.937, Loss:  0.046
# Epoch  19 Batch   53/67 - Train Accuracy:  0.935, Validation Accuracy:  0.941, Loss:  0.047
# Epoch  19 Batch   54/67 - Train Accuracy:  0.937, Validation Accuracy:  0.942, Loss:  0.044
# Epoch  19 Batch   55/67 - Train Accuracy:  0.939, Validation Accuracy:  0.941, Loss:  0.047
# Epoch  19 Batch   56/67 - Train Accuracy:  0.942, Validation Accuracy:  0.939, Loss:  0.040
# Epoch  19 Batch   57/67 - Train Accuracy:  0.940, Validation Accuracy:  0.934, Loss:  0.044
# Epoch  19 Batch   58/67 - Train Accuracy:  0.935, Validation Accuracy:  0.941, Loss:  0.044
# Epoch  19 Batch   59/67 - Train Accuracy:  0.941, Validation Accuracy:  0.937, Loss:  0.041
# Epoch  19 Batch   60/67 - Train Accuracy:  0.934, Validation Accuracy:  0.938, Loss:  0.046
# Epoch  19 Batch   61/67 - Train Accuracy:  0.942, Validation Accuracy:  0.935, Loss:  0.040
# Epoch  19 Batch   62/67 - Train Accuracy:  0.940, Validation Accuracy:  0.941, Loss:  0.043
# Epoch  19 Batch   63/67 - Train Accuracy:  0.930, Validation Accuracy:  0.938, Loss:  0.046
# Epoch  19 Batch   64/67 - Train Accuracy:  0.936, Validation Accuracy:  0.942, Loss:  0.044
# Epoch  19 Batch   65/67 - Train Accuracy:  0.934, Validation Accuracy:  0.937, Loss:  0.045
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
# - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    return None


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('logits:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence], keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in np.argmax(translate_logits, 1)]))
print('  French Words: {}'.format([target_int_to_vocab[i] for i in np.argmax(translate_logits, 1)]))

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  Additionally, the translations in this data set were made by Google translate, so the translations themselves aren't particularly good.  (We apologize to the French speakers out there!) Thankfully, for this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
